# %%
from langchain_community.document_loaders import Docx2txtLoader
from langchain_text_splitters.markdown import MarkdownHeaderTextSplitter
from langchain_text_splitters.character import CharacterTextSplitter
from langchain_openai.embeddings import OpenAIEmbeddings
# Out:
# C:\Users\rabia\AppData\Local\Temp\ipykernel_14704\1449913724.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import Docx2txtLoader

# %%
loader_docx=Docx2txtLoader("Introduction_to_Data_and_Data_Science_2.docx")
pages=loader_docx.load()

# %%
md_splitter =MarkdownHeaderTextSplitter(
    headers_to_split_on=[("#","Course Title"),
                         ("##","Lecture Title")]
)

# %%
pages_md_split=md_splitter.split_text(pages[0].page_content)

# %%
for i in range(len(pages_md_split)):
    pages_md_split[i].page_content=' '.join(pages_md_split[i].page_content.split())

# %%
char_splitter=CharacterTextSplitter(
    separator=".",
    chunk_size=500,
    chunk_overlap=50
)

# %%
pages_char_split=char_splitter.split_documents(pages_md_split)

# %%
pip install langchain-google-genai langchain-community chromadb
# Out:
# Requirement already satisfied: langchain-google-genai in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (4.3.4)
# Requirement already satisfied: langchain-community in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (0.4.2)
# Requirement already satisfied: chromadb in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (1.5.9)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-google-genai) (2.18.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.4 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-google-genai) (1.5.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.56.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (16.1.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (50.0.0)
# Requirement already satisfied: certifi in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (0.10.17)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.7.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=1.26.2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-community) (2.4.6)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: greenlet>=1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.4)
# Requirement already satisfied: build>=1.0.3 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.3)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (1.28.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (4.70.0)
# Requirement already satisfied: overrides>=7.3.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (1.83.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (0.27.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: pyproject_hooks in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: pycparser in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.35.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.27.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: httptools>=0.8.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\rabia\.conda\envs\llms_course_env\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
    pip install -qU langchain-google-genai numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_google_genai import GoogleGenerativeAIEmbeddings


os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6LKRMViqLu8m9RiUCcJCXor6wMM9Jl44TZMvfN5iTsmgg"

# %%
import numpy as np
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
# Option 1: Remove the "models/" prefix
embedding = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2-preview")

# %%
vector1 = embedding.embed_query(pages_char_split[0].page_content)
vector2 = embedding.embed_query(pages_char_split[5].page_content)
vector3 = embedding.embed_query(pages_char_split[18].page_content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\.conda\envs\llms_course_env\Lib\site-packages\langchain_google_genai\embeddings.py:497, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     496 try:
# --> 497     result = self.client.models.embed_content(
#     498         model=self.model,
#     499         contents=text,
#     500         config=config,
#     501     )
#     502 except ClientError as e:
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\google\genai\models.py:6455, in Models.embed_content(self, model, contents, config)
#    6454     contents = t.t_contents(contents)  # type: ignore[assignment]
# -> 6455   return self._embed_content(model=model, contents=contents, config=config)
#    6457 if t.t_is_vertex_embed_content_model(model):
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\google\genai\models.py:5257, in Models._embed_content(self, model, contents, content, embedding_api_type, config)
#    5255 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5257 response = self._api_client.request(
#    5258     'post', path, request_dict, http_options
#    5259 )
#    5261 response_dict = {} if not response.body else json.loads(response.body)
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\google\genai\_api_client.py:1747, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1744 http_request = self._build_request(
#    1745     http_method, path, request_dict, http_options
#    1746 )
# -> 1747 response = self._request(http_request, http_options, stream=False)
#    1748 response_body = (
#    1749     response.response_stream[0] if response.response_stream else ''
#    1750 )
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\google\genai\_api_client.py:1534, in BaseApiClient._request(self, http_request, http_options, stream)
#    1532     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1534 return self._retry(self._request_once, http_request, stream)
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~\.conda\envs\llms_course_env\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\.conda\envs\llms_course_env\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\google\genai\_api_client.py:1511, in BaseApiClient._request_once(self, http_request, stream)
#    1510   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr, arg-type]
# -> 1511 errors.APIError.raise_for_response(response)
#    1512 return HttpResponse(
#    1513     response.headers, response if stream else [response.text]
#    1514 )
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\google\genai\errors.py:173, in APIError.raise_for_response(cls, response)
#     171   response_json = response.body_segments[0].get('error', {})
# --> 173 cls.raise_error(response.status_code, response_json, response)
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\google\genai\errors.py:202, in APIError.raise_error(cls, status_code, response_json, response)
#     201 if 400 <= status_code < 500:
# --> 202   raise ClientError(status_code, response_json, response)
#     203 elif 500 <= status_code < 600:
#
# ClientError: 401 UNAUTHENTICATED. {'error': {'code': 401, 'message': 'Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.', 'status': 'UNAUTHENTICATED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'ACCESS_TOKEN_TYPE_UNSUPPORTED', 'metadata': {'method': 'google.ai.generativelanguage.v1beta.GenerativeService.BatchEmbedContents', 'service': 'generativelanguage.googleapis.com'}}]}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 vector1 = embedding.embed_query(pages_char_split[0].page_content)
#       2 vector2 = embedding.embed_query(pages_char_split[5].page_content)
#       3 vector3 = embedding.embed_query(pages_char_split[18].page_content)
#
# File ~\.conda\envs\llms_course_env\Lib\site-packages\langchain_google_genai\embeddings.py:504, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     502 except ClientError as e:
#     503     msg = f"Error embedding content ({e.status}): {e}"
# --> 504     raise GoogleGenerativeAIError(msg) from e
#     505 except Exception as e:
#     506     msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (UNAUTHENTICATED): 401 UNAUTHENTICATED. {'error': {'code': 401, 'message': 'Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.', 'status': 'UNAUTHENTICATED', 'details': [{'@type': 'type.googleapis.com/google.rpc.ErrorInfo', 'reason': 'ACCESS_TOKEN_TYPE_UNSUPPORTED', 'metadata': {'method': 'google.ai.generativelanguage.v1beta.GenerativeService.BatchEmbedContents', 'service': 'generativelanguage.googleapis.com'}}]}}

# %%
print("Vector Dimensions:", len(vector1), len(vector2), len(vector3))

# %%
print("Similarities:", (
    np.dot(vector1, vector2),
    np.dot(vector1, vector3),
    np.dot(vector2, vector3)
))
